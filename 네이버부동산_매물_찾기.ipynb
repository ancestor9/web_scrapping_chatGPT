# %% [markdown]
# <a href="https://colab.research.google.com/github/ancestor9/web_scrapping_chatGPT/blob/main/%EB%84%A4%EC%9D%B4%EB%B2%84%EB%B6%80%EB%8F%99%EC%82%B0_%EB%A7%A4%EB%AC%BC_%EC%B0%BE%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## [챗GPT로 3분만에 만든 부동산 매물 수집 "소장님들 끝났네요"](https://www.youtube.com/watch?v=V4tjbUQ46Uw&t=116s)

# %%
# prompt: 유튜브 동영상 실행코드 2줄로

from IPython.display import YouTubeVideo
YouTubeVideo('V4tjbUQ46Uw', start=116)

# %% [markdown]
# - https://new.land.naver.com/complexes?ms=37.51506,127.122999,16&a=APT:PRE:ABYG:JGC&e=RETAIL
# 과
# https://new.land.naver.com/complexes?ms=37.504774,127.134595,16&a=APT:PRE:ABYG:JGC&e=RETAIL
#
# 의 차이점은?
# - 네이버 부동산에서 특정 단지의 ID(예: 14472)를 찾는 방법은 다음과 같습니다.
# > - 좌표를 기반으로 단지 ID 찾기 (개발자 도구 활용)
# 네이버 부동산에서 지도 검색
# 원하는 좌표를 포함하는 검색 URL을 사용:
# ruby
# 복사
# 편집
# https://new.land.naver.com/complexes?ms=37.504774,127.134595,16&a=APT:PRE:ABYG:JGC&e=RETAIL
# 지도에서 해당 지역을 탐색하며 단지를 클릭합니다.
# 개발자 도구(F12)로 확인
# 브라우저에서 F12를 눌러 개발자 도구(DevTools)를 엽니다.
# Network 탭으로 이동 후 XHR(Fetch/XHR) 요청을 확인합니다.
# 특정 단지를 클릭할 때 API 요청이 발생하며, 응답 데이터에서 단지 ID를 찾을 수 있습니다.
#
# - json 형태 데이터를 직접 copy하고 notepad에 저장하여 아래와 같이

# %%
text = '''
0
:
{markerId: "125967", markerType: "COMPLEX", latitude: 37.506085, longitude: 127.128925,…}
1
:
{markerId: "127493", markerType: "COMPLEX", latitude: 37.506266, longitude: 127.133037,…}
2
:
{markerId: "138362", markerType: "COMPLEX", latitude: 37.500518, longitude: 127.141813,…}
3
:
{markerId: "135184", markerType: "COMPLEX", latitude: 37.500911, longitude: 127.123069,…}
4
:
{markerId: "119042", markerType: "COMPLEX", latitude: 37.504233, longitude: 127.133899,…}
5
:
{markerId: "148555", markerType: "COMPLEX", latitude: 37.507545, longitude: 127.131945,…}
6
:
{markerId: "9864", markerType: "COMPLEX", latitude: 37.501969, longitude: 127.132013,…}
7
:
{markerId: "139910", markerType: "COMPLEX", latitude: 37.502406, longitude: 127.139155,…}
8
:
{markerId: "122851", markerType: "COMPLEX", latitude: 37.505941, longitude: 127.128775,…}
9
:
{markerId: "100684", markerType: "COMPLEX", latitude: 37.499818, longitude: 127.143522,…}
10
:
{markerId: "9559", markerType: "COMPLEX", latitude: 37.505776, longitude: 127.136052,…}
11
:
{markerId: "130467", markerType: "COMPLEX", latitude: 37.50187, longitude: 127.148176,…}
12
:
{markerId: "3755", markerType: "COMPLEX", latitude: 37.501578, longitude: 127.141088,…}
13
:
{markerId: "23150", markerType: "COMPLEX", latitude: 37.50943, longitude: 127.13261,…}
14
:
{markerId: "138966", markerType: "COMPLEX", latitude: 37.509895, longitude: 127.130549,…}
15
:
{markerId: "121671", markerType: "COMPLEX", latitude: 37.506105, longitude: 127.130914,…}
16
:
{markerId: "107948", markerType: "COMPLEX", latitude: 37.503516, longitude: 127.128941,…}
17
85
:
{markerId: "26692", markerType: "COMPLEX", latitude: 37.505431, longitude: 127.133217,…}
86
:
{markerId: "115606", markerType: "COMPLEX", latitude: 37.501079, longitude: 127.145735,…}
87
:
{markerId: "104145", markerType: "COMPLEX", latitude: 37.506611, longitude: 127.13188,…}
88
:
{markerId: "26690", markerType: "COMPLEX", latitude: 37.499546, longitude: 127.143071,…}
89
:
{markerId: "125739", markerType: "COMPLEX", latitude: 37.501279, longitude: 127.141564,…}
90
:
{markerId: "112628", markerType: "COMPLEX", latitude: 37.502394, longitude: 127.134349,…}
91
:
{markerId: "3552", markerType: "COMPLEX", latitude: 37.510012, longitude: 127.123934,…}
92
:
{markerId: "26268", markerType: "COMPLEX", latitude: 37.507354, longitude: 127.121567,…}
93
:
{markerId: "27109", markerType: "COMPLEX", latitude: 37.499517, longitude: 127.14356,…}
94
:
{markerId: "128195", markerType: "COMPLEX", latitude: 37.502639, longitude: 127.138838,…}
95
:
{markerId: "9327", markerType: "COMPLEX", latitude: 37.501554, longitude: 127.132877,…}
96
:
{markerId: "1197", markerType: "COMPLEX", latitude: 37.503949, longitude: 127.124263,…}
97
:
{markerId: "141001", markerType: "COMPLEX", latitude: 37.503136, longitude: 127.138557,…}
98
:
{markerId: "632", markerType: "COMPLEX", latitude: 37.506558, longitude: 127.126842,…}
99
:
{markerId: "612", markerType: "COMPLEX", latitude: 37.508844, longitude: 127.1231, complexName: "코오롱",…}
'''

# %%
# prompt: text를 'b.txt' 파일로 저장하는 코드 3줄이내로

with open('b.txt', 'w') as f:
  f.write(text)

# %%
import pandas as pd

# %%
# prompt: /content/b.txt 를 읽어줘

import pandas as pd

# 파일 읽기
try:
  with open('/content/b.txt', 'r') as file:
    contents = file.read()
    print(contents)
except FileNotFoundError:
  print("파일을 찾을 수 없습니다.")
# Out:
# 0
# :
# {markerId: "125967", markerType: "COMPLEX", latitude: 37.506085, longitude: 127.128925,…}
# 1
# :
# {markerId: "127493", markerType: "COMPLEX", latitude: 37.506266, longitude: 127.133037,…}
# 2
# :
# {markerId: "138362", markerType: "COMPLEX", latitude: 37.500518, longitude: 127.141813,…}
# 3
# :
# {markerId: "135184", markerType: "COMPLEX", latitude: 37.500911, longitude: 127.123069,…}
# 4
# :
# {markerId: "119042", markerType: "COMPLEX", latitude: 37.504233, longitude: 127.133899,…}
# 5
# :
# {markerId: "148555", markerType: "COMPLEX", latitude: 37.507545, longitude: 127.131945,…}
# 6
# :
# {markerId: "9864", markerType: "COMPLEX", latitude: 37.501969, longitude: 127.132013,…}
# 7
# :
# {markerId: "139910", markerType: "COMPLEX", latitude: 37.502406, longitude: 127.139155,…}
# 8
# :
# {markerId: "122851", markerType: "COMPLEX", latitude: 37.505941, longitude: 127.128775,…}
# 9
# :
# {markerId: "100684", markerType: "COMPLEX", latitude: 37.499818, longitude: 127.143522,…}
# ...

# %%
import re
# 정규 표현식 패턴: markerId 값 추출 chatGPT
pattern = r'markerId:\s*"(\d+)"'

# 정규 표현식 실행
marker_ids = re.findall(pattern, contents)

# 출력
marker_ids
# Out:
# ['125967',
#  '127493',
#  '138362',
#  '135184',
#  '119042',
#  '148555',
#  '9864',
#  '139910',
#  '122851',
#  '100684',
#  '9559',
#  '130467',
#  '3755',
#  '23150',
#  '138966',
#  '121671',
#  '107948',
#  '101229',
#  '613',
#  '104458',
#  '118141',
#  '114947',
#  '16150',
#  '154906',
#  '158997',
#  '122521',
#  '23941',
#  '14252',
#  '22217',
#  '12949',
#  '122918',
#  '9361',
#  '631',
#  '12922',
#  '633',
#  '3428',
#  '615',
#  '161159',
#  '611',
#  '14685',
#  '26679',
#  '135563',
#  '124145',
#  '10899',
#  '108056',
#  '26684',
#  '151939',
#  '12124',
#  '26267',
#  '142240',
#  '126162',
#  '100837',
#  '27110',
#  '117840',
#  '13684',
#  '26682',
#  '14240',
#  '3756',
#  '14468',
#  '602',
#  '125916',
#  '128896',
#  '118529',
#  '104729',
#  '156872',
#  '105731',
#  '8577',
#  '11973',
#  '24956',
#  '113142',
#  '11256',
#  '607',
#  '114818',
#  '152624',
#  '173682',
#  '147185',
#  '14472',
#  '22688',
#  '1196',
#  '115869',
#  '25251',
# ...

# %%
# prompt: marker_ids 를 모두 정수로 변환하기

# marker_ids 리스트의 요소들을 정수로 변환
marker_ids = [int(id) for id in marker_ids]

# 출력
marker_ids
# Out:
# [125967,
#  127493,
#  138362,
#  135184,
#  119042,
#  148555,
#  9864,
#  139910,
#  122851,
#  100684,
#  9559,
#  130467,
#  3755,
#  23150,
#  138966,
#  121671,
#  107948,
#  101229,
#  613,
#  104458,
#  118141,
#  114947,
#  16150,
#  154906,
#  158997,
#  122521,
#  23941,
#  14252,
#  22217,
#  12949,
#  122918,
#  9361,
#  631,
#  12922,
#  633,
#  3428,
#  615,
#  161159,
#  611,
#  14685,
#  26679,
#  135563,
#  124145,
#  10899,
#  108056,
#  26684,
#  151939,
#  12124,
#  26267,
#  142240,
#  126162,
#  100837,
#  27110,
#  117840,
#  13684,
#  26682,
#  14240,
#  3756,
#  14468,
#  602,
#  125916,
#  128896,
#  118529,
#  104729,
#  156872,
#  105731,
#  8577,
#  11973,
#  24956,
#  113142,
#  11256,
#  607,
#  114818,
#  152624,
#  173682,
#  147185,
#  14472,
#  22688,
#  1196,
#  115869,
#  25251,
#  125353,
#  125078,
#  148397,
#  125361,
#  26692,
#  115606,
#  104145,
#  26690,
#  125739,
#  112628,
#  3552,
#  26268,
#  27109,
#  128195,
#  9327,
#  1197,
# ...

# %% [markdown]
# ### **동영상 보면서 하기**

# %%
YouTubeVideo('V4tjbUQ46Uw', start=90)

# %% [markdown]
# https://new.land.naver.com/api/articles/complex/111515?realEstateType=APT%3APRE%3AABYG%3AJGC&tradeType=&tag=%3A%3A%3A%3A%3A%3A%3A%3A&rentPriceMin=0&rentPriceMax=900000000&priceMin=0&priceMax=900000000&areaMin=0&areaMax=900000000&oldBuildYears&recentlyBuildYears&minHouseHoldCount&maxHouseHoldCount&showArticle=false&sameAddressGroup=false&minMaintenanceCost&maxMaintenanceCost&priceType=RETAIL&directions=&page=1&complexNo=111515&buildingNos=&areaNos=&type=list&order=rank

# %%
# prompt: /content/realestate.jpg 를 시각화 해줘

from IPython.display import Image

try:
  display(Image('/content/realestate.jpg'))
except FileNotFoundError:
  print("Error: /content/realestate.jpg not found.")

# %%
import requests

cookies = {
    'NNB': 'ATDCZU4KXWMGO',
    'NACT': '1',
    'nhn.realestate.article.rlet_type_cd': 'A01',
    'nhn.realestate.article.trade_type_cd': '""',
    'nhn.realestate.article.ipaddress_city': '1100000000',
    '_fwb': '181EyXL2zPnHhRH8x1NXS9G.1738154372891',
    'landHomeFlashUseYn': 'Y',
    '_fwb': '181EyXL2zPnHhRH8x1NXS9G.1738154372891',
    'NAC': 'oD3JBcw7DnPb',
    'SHOW_FIN_BADGE': 'Y',
    'realestate.beta.lastclick.cortar': '1171000000',
    'BUC': 'wq95qLwHQCkZZ8KLH0QMRAuxkK0uAleIJnJ4O-oIkWc=',
    'REALESTATE': 'Thu%20Jan%2030%202025%2013%3A24%3A48%20GMT%2B0900%20(Korean%20Standard%20Time)',
}

headers = {
    'accept': '*/*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IlJFQUxFU1RBVEUiLCJpYXQiOjE3MzgyMTEwODgsImV4cCI6MTczODIyMTg4OH0.1NoMib6T-gEOJxHWO_dRjU7k2Eh4kpdgN7vzGoaoFms',
    'cache-control': 'no-cache',
    # 'cookie': 'NNB=ATDCZU4KXWMGO; NACT=1; nhn.realestate.article.rlet_type_cd=A01; nhn.realestate.article.trade_type_cd=""; nhn.realestate.article.ipaddress_city=1100000000; _fwb=181EyXL2zPnHhRH8x1NXS9G.1738154372891; landHomeFlashUseYn=Y; _fwb=181EyXL2zPnHhRH8x1NXS9G.1738154372891; NAC=oD3JBcw7DnPb; SHOW_FIN_BADGE=Y; realestate.beta.lastclick.cortar=1171000000; BUC=wq95qLwHQCkZZ8KLH0QMRAuxkK0uAleIJnJ4O-oIkWc=; REALESTATE=Thu%20Jan%2030%202025%2013%3A24%3A48%20GMT%2B0900%20(Korean%20Standard%20Time)',
    'pragma': 'no-cache',
    'priority': 'u=1, i',
    'referer': 'https://new.land.naver.com/complexes/111515?ms=37.4980071,127.1073753,17&a=APT:PRE:ABYG:JGC&e=RETAIL',
    'sec-ch-ua': '"Not A(Brand";v="8", "Chromium";v="132", "Google Chrome";v="132"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36',
}

response = requests.get(
    'https://new.land.naver.com/api/articles/complex/111515?realEstateType=APT%3APRE%3AABYG%3AJGC&tradeType=&tag=%3A%3A%3A%3A%3A%3A%3A%3A&rentPriceMin=0&rentPriceMax=900000000&priceMin=0&priceMax=900000000&areaMin=0&areaMax=900000000&oldBuildYears&recentlyBuildYears&minHouseHoldCount&maxHouseHoldCount&showArticle=false&sameAddressGroup=false&minMaintenanceCost&maxMaintenanceCost&priceType=RETAIL&directions=&page=1&complexNo=111515&buildingNos=&areaNos=&type=list&order=rank',
    cookies=cookies,
    headers=headers,
)

# %%
response
# Out:
# <Response [200]>

# %%
# page1의 부동산 매물이 올라옴
response.text
# Out:
# '{"isMoreData":true,"articleList":[{"articleNo":"2504255218","articleName":"헬리오시티","articleStatus":"R0","realEstateTypeCode":"APT","realEstateTypeName":"아파트","articleRealEstateTypeCode":"A01","articleRealEstateTypeName":"아파트","tradeTypeCode":"B2","tradeTypeName":"월세","verificationTypeCode":"SITE","floorInfo":"27/35","rentPrc":"280","priceChangeState":"SAME","isPriceModification":false,"dealOrWarrantPrc":"4억","areaName":"109E","area1":109,"area2":84,"direction":"남향","articleConfirmYmd":"20250124","representativeImgUrl":"/20250124_191/1737710409389F1Ub3_JPEG/1cc447706359b99274746265ff8932c1.JPG","representativeImgTypeCode":"SITE","representativeImgThumb":"f130_98","siteImageCount":14,"articleFeatureDesc":"보증금조정가능, 빼어난 뷰, 상태 아주 좋음","tagList":["10년이내","대단지","방세개","화장실두개"],"buildingName":"109동","sameAddrCnt":1,"sameAddrDirectCnt":0,"sameAddrMaxPrc":"4억/280","sameAddrMinPrc":"4억/280","cpid":"bizmk","cpName":"매경부동산","cpPcArticleUrl":"http://land.mk.co.kr/rd/rd.php?UID=2504255218","cpPcArtic
# ...

# %%
# prompt: 'https://new.land.naver.com/api/articles/complex/111515?realEstateType=APT%3APRE%3AABYG%3AJGC&tradeType=&tag=%3A%3A%3A%3A%3A%3A%3A%3A&rentPriceMin=0&rentPriceMax=900000000&priceMin=0&priceMax=900000000&areaMin=0&areaMax=900000000&oldBuildYears&recentlyBuildYears&minHouseHoldCount&maxHouseHoldCount&showArticle=false&sameAddressGroup=false&minMaintenanceCost&maxMaintenanceCost&priceType=RETAIL&directions=&page=1&complexNo=111515&buildingNos=&areaNos=&type=list&order=rank',
# 에서 page를 찾으려면

import re

url = 'https://new.land.naver.com/api/articles/complex/111515?realEstateType=APT%3APRE%3AABYG%3AJGC&tradeType=&tag=%3A%3A%3A%3A%3A%3A%3A%3A&rentPriceMin=0&rentPriceMax=900000000&priceMin=0&priceMax=900000000&areaMin=0&areaMax=900000000&oldBuildYears&recentlyBuildYears&minHouseHoldCount&maxHouseHoldCount&showArticle=false&sameAddressGroup=false&minMaintenanceCost&maxMaintenanceCost&priceType=RETAIL&directions=&page=1&complexNo=111515&buildingNos=&areaNos=&type=list&order=rank'

# 정규 표현식을 사용하여 URL에서 page 값을 추출합니다.
match = re.search(r'page=(\d+)', url)

if match:
  page_number = match.group(1)
  print(f"Page number: {page_number}")
else:
  print("Page number not found in the URL.")
# Out:
# Page number: 1

# %% [markdown]
# ### **chatGPT**

# %%
import requests
import pandas as pd

# 설정된 쿠키 및 헤더
cookies = {
    'NNB': 'ATDCZU4KXWMGO',
    'NACT': '1',
    'nhn.realestate.article.rlet_type_cd': 'A01',
    'nhn.realestate.article.trade_type_cd': '""',
    'nhn.realestate.article.ipaddress_city': '1100000000',
    '_fwb': '181EyXL2zPnHhRH8x1NXS9G.1738154372891',
    'landHomeFlashUseYn': 'Y',
    'NAC': 'oD3JBcw7DnPb',
    'SHOW_FIN_BADGE': 'Y',
    'realestate.beta.lastclick.cortar': '1171000000',
    'BUC': 'wq95qLwHQCkZZ8KLH0QMRAuxkK0uAleIJnJ4O-oIkWc=',
    'REALESTATE': 'Thu%20Jan%2030%202025%2013%3A24%3A48%20GMT%2B0900%20(Korean%20Standard%20Time)',
}

headers = {
    'accept': '*/*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IlJFQUxFU1RBVEUiLCJpYXQiOjE3MzgyMTEwODgsImV4cCI6MTczODIyMTg4OH0.1NoMib6T-gEOJxHWO_dRjU7k2Eh4kpdgN7vzGoaoFms',
    'cache-control': 'no-cache',
    'pragma': 'no-cache',
    'priority': 'u=1, i',
    'referer': 'https://new.land.naver.com/complexes/111515?ms=37.4980071,127.1073753,17&a=APT:PRE:ABYG:JGC&e=RETAIL',
    'sec-ch-ua': '"Not A(Brand";v="8", "Chromium";v="132", "Google Chrome";v="132"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36',
}

# 요청 URL
url = 'https://new.land.naver.com/api/articles/complex/111515?realEstateType=APT%3APRE%3AABYG%3AJGC&tradeType=&tag=%3A%3A%3A%3A%3A%3A%3A%3A&rentPriceMin=0&rentPriceMax=900000000&priceMin=0&priceMax=900000000&areaMin=0&areaMax=900000000&oldBuildYears&recentlyBuildYears&minHouseHoldCount&maxHouseHoldCount&showArticle=false&sameAddressGroup=false&minMaintenanceCost&maxMaintenanceCost&priceType=RETAIL&directions=&page=1&complexNo=111515&buildingNos=&areaNos=&type=list&order=rank'

# 데이터 요청
response = requests.get(url, cookies=cookies, headers=headers)
data = response.json()

# 필요한 데이터 추출
articles = data.get('articleList', [])

# 데이터 정리
real_estate_data = []
for article in articles:
    real_estate_data.append({
        '매물번호': article.get('articleNo', ''),
        '매물명': article.get('articleName', ''),
        '유형': article.get('realEstateTypeName', ''),
        '거래유형': article.get('tradeTypeName', ''),
        '층수': article.get('floorInfo', ''),
        '보증금/매매가': article.get('dealOrWarrantPrc', ''),
        '월세': article.get('rentPrc', ''),
        '전용면적': article.get('area2', ''),
        '방향': article.get('direction', ''),
        '확인일자': article.get('articleConfirmYmd', ''),
        '특징': article.get('articleFeatureDesc', ''),
        '건물명': article.get('buildingName', ''),
        '중개사': article.get('realtorName', ''),
        '위도': article.get('latitude', ''),
        '경도': article.get('longitude', ''),
        '매물링크': article.get('cpPcArticleUrl', '')
    })

# 데이터프레임 생성
df = pd.DataFrame(real_estate_data)

# CSV 저장
csv_filename = "real_estate_listings.csv"
df.to_csv(csv_filename, index=False, encoding="utf-8-sig")

# 결과 파일 경로 출력
csv_filename
# Out:
# 'real_estate_listings.csv'

# %%
df
# Out:
#           매물번호    매물명   유형 거래유형     층수    보증금/매매가   월세  전용면적   방향      확인일자  \
# 0   2504255218  헬리오시티  아파트   월세  27/35         4억  280    84   남향  20250124
# 1   2504901612  헬리오시티  아파트   전세  28/29        12억         84   남향  20250130
# 2   2504910248  헬리오시티  아파트   전세   5/35  13억 8,000        110   남향  20250130
# 3   2504901492  헬리오시티  아파트   매매  10/19        20억         59  남서향  20250130
# 4   2504910169  헬리오시티  아파트   매매   4/35        23억         84  남서향  20250130
# 5   2504912259  헬리오시티  아파트   매매  11/35  28억 5,000        110   남향  20250130
# 6   2504901508  헬리오시티  아파트   매매  11/35  27억 3,000        110   남향  20250130
# 7   2504901012  헬리오시티  아파트   전세  15/35  14억 5,000        110   남향  20250130
# 8   2504911196  헬리오시티  아파트   매매  21/35        23억         84   남향  20250130
# 9   2504912383  헬리오시티  아파트   전세  15/35        15억        110   남향  20250130
# 10  2504912293  헬리오시티  아파트   매매  15/35  28억 5,000        110   남향  20250130
# ...
